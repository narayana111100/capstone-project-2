# %% [markdown]
# <a href="https://colab.research.google.com/github/narayana111100/capstone-project-2/blob/main/CASE_STUDY___TOURISM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd  
import numpy as np   
import matplotlib.pyplot as plt 
# %matplotlib inline    
import seaborn as sns   
sns.set(color_codes = True)
pd.set_option('max_columns', None)
pd.set_option('max_rows', None)

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df= pd.read_csv("/content/drive/MyDrive/train_small.csv")

# %%
df.head()
# Out:
#    search_id            timestamp  site_id  user_country_id  user_hist_stars  \
# 0          4  2012-12-31 08:59:22        5              219              NaN
# 1          4  2012-12-31 08:59:22        5              219              NaN
# 2          4  2012-12-31 08:59:22        5              219              NaN
# 3          4  2012-12-31 08:59:22        5              219              NaN
# 4          4  2012-12-31 08:59:22        5              219              NaN
#
#    user_hist_paid  listing_country_id  listing_id  listing_stars  \
# 0             NaN                 219        3625              4
# 1             NaN                 219       11622              4
# 2             NaN                 219       11826              5
# 3             NaN                 219       22824              3
# 4             NaN                 219       37581              5
#
#    listing_review_score  is_brand  location_score1  location_score2  \
# 0                   4.0         0             3.22           0.2544
# 1                   4.0         0             2.71              NaN
# 2                   4.5         1             3.22           0.1924
# 3                   4.0         0             3.26           0.3729
# 4                   4.5         0             3.09           0.2508
#
#    log_historical_price  listing_position  price_usd  has_promotion  \
# 0                  5.98                21      295.0              0
# 1                  5.64                36      299.0              0
# 2                  6.10                22      373.0              1
# 3                  5.74                 4      329.0              0
# 4                  6.21                26      600.0              0
#
#    destination_id  length_of_stay  booking_window  num_adults  num_kids  \
# 0           12588               2              46           1         0
# 1           12588               2              46           1         0
# 2           12588               2              46           1         0
# 3           12588               2              46           1         0
# 4           12588               2              46           1         0
#
#    num_rooms  stay_on_saturday  log_click_proportion  distance_to_dest  \
# 0          1                 1                   NaN            238.35
# 1          1                 1                   NaN            238.34
# 2          1                 1                   NaN            238.33
# 3          1                 1                   NaN            238.29
# 4          1                 1                   NaN            238.35
#
#    random_sort  competitor1_rate  competitor1_has_availability  \
# 0            1               NaN                           NaN
# 1            1               NaN                           NaN
# 2            1               NaN                           NaN
# 3            1               NaN                           NaN
# 4            1               NaN                           NaN
#
#    competitor1_price_percent_diff  competitor2_rate  \
# 0                             NaN               NaN
# 1                             NaN               NaN
# 2                             NaN               NaN
# 3                             NaN               NaN
# 4                             NaN               NaN
#
#    competitor2_has_availability  competitor2_price_percent_diff  \
# 0                           NaN                             NaN
# 1                           NaN                             NaN
# 2                           NaN                             NaN
# 3                           NaN                             NaN
# 4                           NaN                             NaN
#
#    competitor3_rate  competitor3_has_availability  \
# 0               NaN                           NaN
# 1               NaN                           NaN
# 2               NaN                           NaN
# 3               NaN                           NaN
# 4               NaN                           NaN
#
#    competitor3_price_percent_diff  competitor4_rate  \
# 0                             NaN               NaN
# 1                             NaN               NaN
# 2                             NaN               NaN
# 3                             NaN               NaN
# 4                             NaN               NaN
#
#    competitor4_has_availability  competitor4_price_percent_diff  \
# 0                           NaN                             NaN
# 1                           NaN                             NaN
# 2                           NaN                             NaN
# 3                           NaN                             NaN
# 4                           NaN                             NaN
#
#    competitor5_rate  competitor5_has_availability  \
# 0               NaN                           NaN
# 1               NaN                           NaN
# 2               NaN                           NaN
# 3               NaN                           NaN
# 4               NaN                           NaN
#
#    competitor5_price_percent_diff  competitor6_rate  \
# 0                             NaN               NaN
# 1                             NaN               NaN
# 2                             NaN               NaN
# 3                             NaN               NaN
# 4                             NaN               NaN
#
#    competitor6_has_availability  competitor6_price_percent_diff  \
# 0                           NaN                             NaN
# 1                           NaN                             NaN
# 2                           NaN                             NaN
# 3                           NaN                             NaN
# 4                           NaN                             NaN
#
#    competitor7_rate  competitor7_has_availability  \
# 0               NaN                           NaN
# 1               NaN                           NaN
# 2               NaN                           NaN
# 3               NaN                           NaN
# 4               NaN                           NaN
#
#    competitor7_price_percent_diff  competitor8_rate  \
# 0                             NaN               NaN
# 1                             NaN               NaN
# 2                             NaN               NaN
# 3                             NaN               NaN
# 4                             NaN               NaN
#
#    competitor8_has_availability  competitor8_price_percent_diff  clicked  \
# 0                           NaN                             NaN        0
# 1                           NaN                             NaN        0
# 2                           NaN                             NaN        0
# 3                           NaN                             NaN        0
# 4                           NaN                             NaN        0
#
#    booking_value  booked
# 0            NaN       0
# 1            NaN       0
# 2            NaN       0
# 3            NaN       0
# 4            NaN       0

# %%
df1=df.copy()

# %%
df.shape
# Out:
# (2380557, 54)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2380557 entries, 0 to 2380556
# Data columns (total 54 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   search_id                       int64
#  1   timestamp                       object
#  2   site_id                         int64
#  3   user_country_id                 int64
#  4   user_hist_stars                 float64
#  5   user_hist_paid                  float64
#  6   listing_country_id              int64
#  7   listing_id                      int64
#  8   listing_stars                   int64
#  9   listing_review_score            float64
#  10  is_brand                        int64
#  11  location_score1                 float64
#  12  location_score2                 float64
#  13  log_historical_price            float64
#  14  listing_position                int64
#  15  price_usd                       float64
#  16  has_promotion                   int64
#  17  destination_id                  int64
#  18  length_of_stay                  int64
#  19  booking_window                  int64
#  20  num_adults                      int64
#  21  num_kids                        int64
#  22  num_rooms                       int64
#  23  stay_on_saturday                int64
#  24  log_click_proportion            float64
#  25  distance_to_dest                float64
#  26  random_sort                     int64
#  27  competitor1_rate                float64
#  28  competitor1_has_availability    float64
#  29  competitor1_price_percent_diff  float64
#  30  competitor2_rate                float64
#  31  competitor2_has_availability    float64
#  32  competitor2_price_percent_diff  float64
#  33  competitor3_rate                float64
#  34  competitor3_has_availability    float64
#  35  competitor3_price_percent_diff  float64
#  36  competitor4_rate                float64
#  37  competitor4_has_availability    float64
#  38  competitor4_price_percent_diff  float64
#  39  competitor5_rate                float64
#  40  competitor5_has_availability    float64
#  41  competitor5_price_percent_diff  float64
#  42  competitor6_rate                float64
#  43  competitor6_has_availability    float64
#  44  competitor6_price_percent_diff  float64
#  45  competitor7_rate                float64
#  46  competitor7_has_availability    float64
#  47  competitor7_price_percent_diff  float64
#  48  competitor8_rate                float64
#  49  competitor8_has_availability    float64
#  50  competitor8_price_percent_diff  float64
#  51  clicked                         int64
#  52  booking_value                   float64
#  53  booked                          int64
# dtypes: float64(34), int64(19), object(1)
# memory usage: 980.8+ MB

# %%
df.nunique()/len(df)*100
# Out:
# search_id                          4.026033
# timestamp                          4.014943
# site_id                            0.001428
# user_country_id                    0.008065
# user_hist_stars                    0.012266
# user_hist_paid                     0.182520
# listing_country_id                 0.006973
# listing_id                         4.930695
# listing_stars                      0.000252
# listing_review_score               0.000420
# is_brand                           0.000084
# location_score1                    0.014156
# location_score2                    0.381507
# log_historical_price               0.016005
# listing_position                   0.001680
# price_usd                          2.634341
# has_promotion                      0.000084
# destination_id                     0.551216
# length_of_stay                     0.001386
# booking_window                     0.016467
# num_adults                         0.000378
# num_kids                           0.000420
# num_rooms                          0.000336
# stay_on_saturday                   0.000084
# log_click_proportion               4.880580
# distance_to_dest                  16.230949
# random_sort                        0.000084
# competitor1_rate                   0.000126
# competitor1_has_availability       0.000126
# competitor1_price_percent_diff     0.045830
# competitor2_rate                   0.000126
# competitor2_has_availability       0.000126
# competitor2_price_percent_diff     0.019617
# competitor3_rate                   0.000126
# competitor3_has_availability       0.000126
# competitor3_price_percent_diff     0.018525
# competitor4_rate                   0.000126
# competitor4_has_availability       0.000126
# competitor4_price_percent_diff     0.015753
# competitor5_rate                   0.000126
# competitor5_has_availability       0.000126
# competitor5_price_percent_diff     0.020751
# competitor6_rate                   0.000126
# competitor6_has_availability       0.000126
# competitor6_price_percent_diff     0.012602
# competitor7_rate                   0.000126
# competitor7_has_availability       0.000126
# competitor7_price_percent_diff     0.020079
# competitor8_rate                   0.000126
# competitor8_has_availability       0.000126
# competitor8_price_percent_diff     0.015837
# clicked                            0.000084
# booking_value                      1.662930
# booked                             0.000084
# dtype: float64

# %%
df.columns
# Out:
# Index(['search_id', 'timestamp', 'site_id', 'user_country_id',
#        'user_hist_stars', 'user_hist_paid', 'listing_country_id', 'listing_id',
#        'listing_stars', 'listing_review_score', 'is_brand', 'location_score1',
#        'location_score2', 'log_historical_price', 'listing_position',
#        'price_usd', 'has_promotion', 'destination_id', 'length_of_stay',
#        'booking_window', 'num_adults', 'num_kids', 'num_rooms',
#        'stay_on_saturday', 'log_click_proportion', 'distance_to_dest',
#        'random_sort', 'competitor1_rate', 'competitor1_has_availability',
#        'competitor1_price_percent_diff', 'competitor2_rate',
#        'competitor2_has_availability', 'competitor2_price_percent_diff',
#        'competitor3_rate', 'competitor3_has_availability',
#        'competitor3_price_percent_diff', 'competitor4_rate',
#        'competitor4_has_availability', 'competitor4_price_percent_diff',
#        'competitor5_rate', 'competitor5_has_availability',
#        'competitor5_price_percent_diff', 'competitor6_rate',
#        'competitor6_has_availability', 'competitor6_price_percent_diff',
#        'competitor7_rate', 'competitor7_has_availability',
#        'competitor7_price_percent_diff', 'competitor8_rate',
#        'competitor8_has_availability', 'competitor8_price_percent_diff',
#        'clicked', 'booking_value', 'booked'],
#       dtype='object')

# %% [markdown]
# FEATURE ENGINEERING

# %%
df_new = df.drop(['competitor1_rate','competitor2_rate','competitor3_rate','competitor4_rate','competitor5_rate','competitor6_rate','competitor7_rate',
                  'competitor8_rate','competitor1_price_percent_diff','competitor2_price_percent_diff','competitor3_price_percent_diff','competitor4_price_percent_diff',
                  'competitor5_price_percent_diff','competitor6_price_percent_diff','competitor7_price_percent_diff','competitor8_price_percent_diff',
                  'competitor1_has_availability','competitor2_has_availability','competitor3_has_availability','competitor4_has_availability',
                  'competitor5_has_availability','competitor6_has_availability','competitor7_has_availability','competitor8_has_availability','user_hist_stars', 'user_hist_paid','booking_value','log_click_proportion'], axis=1)

# %%
df_new.columns
# Out:
# Index(['search_id', 'timestamp', 'site_id', 'user_country_id',
#        'listing_country_id', 'listing_id', 'listing_stars',
#        'listing_review_score', 'is_brand', 'location_score1',
#        'location_score2', 'log_historical_price', 'listing_position',
#        'price_usd', 'has_promotion', 'destination_id', 'length_of_stay',
#        'booking_window', 'num_adults', 'num_kids', 'num_rooms',
#        'stay_on_saturday', 'distance_to_dest', 'random_sort', 'clicked',
#        'booked'],
#       dtype='object')

# %%
df_new.shape
# Out:
# (2380557, 26)

# %%
df['timestamp'].unique()
# Out:
# array(['2012-12-31 08:59:22', '2012-11-26 10:13:17',
#        '2013-02-11 01:28:38', ..., '2013-04-22 10:48:23',
#        '2013-06-26 09:29:47', '2013-03-30 16:39:40'], dtype=object)

# %%
df['timestamp'].nunique()
# Out:
# 95578

# %%
df_new.isnull().sum()/len(df)*100
# Out:
# search_id                0.000000
# timestamp                0.000000
# site_id                  0.000000
# user_country_id          0.000000
# listing_country_id       0.000000
# listing_id               0.000000
# listing_stars            0.000000
# listing_review_score     0.146436
# is_brand                 0.000000
# location_score1          0.000000
# location_score2         22.095333
# log_historical_price     0.000000
# listing_position         0.000000
# price_usd                0.000000
# has_promotion            0.000000
# destination_id           0.000000
# length_of_stay           0.000000
# booking_window           0.000000
# num_adults               0.000000
# num_kids                 0.000000
# num_rooms                0.000000
# stay_on_saturday         0.000000
# distance_to_dest        32.359486
# random_sort              0.000000
# clicked                  0.000000
# booked                   0.000000
# dtype: float64

# %%
df_new.columns
# Out:
# Index(['search_id', 'timestamp', 'site_id', 'user_country_id',
#        'listing_country_id', 'listing_id', 'listing_stars',
#        'listing_review_score', 'is_brand', 'location_score1',
#        'location_score2', 'log_historical_price', 'listing_position',
#        'price_usd', 'has_promotion', 'destination_id', 'length_of_stay',
#        'booking_window', 'num_adults', 'num_kids', 'num_rooms',
#        'stay_on_saturday', 'distance_to_dest', 'random_sort', 'clicked',
#        'booked'],
#       dtype='object')

# %%
df_new.drop(['search_id', 'timestamp', 'site_id','destination_id','listing_id','user_country_id', 'listing_country_id'],axis=1,inplace= True)

# %%
df_new.isnull().sum()/len(df)*100
# Out:
# listing_stars            0.000000
# listing_review_score     0.146436
# is_brand                 0.000000
# location_score1          0.000000
# location_score2         22.095333
# log_historical_price     0.000000
# listing_position         0.000000
# price_usd                0.000000
# has_promotion            0.000000
# length_of_stay           0.000000
# booking_window           0.000000
# num_adults               0.000000
# num_kids                 0.000000
# num_rooms                0.000000
# stay_on_saturday         0.000000
# distance_to_dest        32.359486
# random_sort              0.000000
# clicked                  0.000000
# booked                   0.000000
# dtype: float64

# %% [markdown]
# FINDING NULL VALUES

# %%
from scipy.stats import skew

# %%
df_new.skew()
# Out:
# listing_stars            -0.666650
# listing_review_score     -2.242337
# is_brand                 -0.559432
# location_score1           0.132128
# location_score2           1.950508
# log_historical_price     -1.726552
# listing_position          0.179594
# price_usd               453.804919
# has_promotion             1.388013
# length_of_stay            3.484501
# booking_window            2.399389
# num_adults                2.328857
# num_kids                  2.465520
# num_rooms                 6.344249
# stay_on_saturday          0.006935
# distance_to_dest          2.348897
# random_sort               0.889906
# clicked                   4.414166
# booked                    5.734716
# dtype: float64

# %%
df_new.head()
# Out:
#    listing_stars  listing_review_score  is_brand  location_score1  \
# 0              4                   4.0         0             3.22
# 1              4                   4.0         0             2.71
# 2              5                   4.5         1             3.22
# 3              3                   4.0         0             3.26
# 4              5                   4.5         0             3.09
#
#    location_score2  log_historical_price  listing_position  price_usd  \
# 0           0.2544                  5.98                21      295.0
# 1              NaN                  5.64                36      299.0
# 2           0.1924                  6.10                22      373.0
# 3           0.3729                  5.74                 4      329.0
# 4           0.2508                  6.21                26      600.0
#
#    has_promotion  length_of_stay  booking_window  num_adults  num_kids  \
# 0              0               2              46           1         0
# 1              0               2              46           1         0
# 2              1               2              46           1         0
# 3              0               2              46           1         0
# 4              0               2              46           1         0
#
#    num_rooms  stay_on_saturday  distance_to_dest  random_sort  clicked  booked
# 0          1                 1            238.35            1        0       0
# 1          1                 1            238.34            1        0       0
# 2          1                 1            238.33            1        0       0
# 3          1                 1            238.29            1        0       0
# 4          1                 1            238.35            1        0       0

# %% [markdown]
# HANDLING OF NULL VALUE

# %%
for i in df_new:
  df_new[i].fillna(df[i].median(),inplace = True)

# %% [markdown]
# LISTING OF STARS

# %%
df_new['listing_stars'].value_counts()/len(df)*100
# Out:
# 3    39.260140
# 4    30.664168
# 2    18.061865
# 5     8.229965
# 0     3.433818
# 1     0.350044
# Name: listing_stars, dtype: float64

# %%
#The star rating of the hotel, from 1 to 5, in increments of 1.  A 0 indicates the property has no stars, the star rating is not known or cannot be publicized.

sns.set_style('white')
plt.figure(figsize=(10,7))
sns.countplot(df_new['listing_stars'])
plt.title('listing_stars')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_new['listing_review_score'].value_counts()/len(df)*100
# Out:
# 4.0    31.546063
# 4.5    31.243948
# 3.5    15.459323
# 3.0     7.575790
# 5.0     4.790770
# 0.0     4.695540
# 2.5     2.889282
# 2.0     1.234501
# 1.5     0.292032
# 1.0     0.272751
# Name: listing_review_score, dtype: float64

# %%
plt.style.use('default')
plt.figure(figsize=(20, 7))
sns.countplot(df_new['num_adults'], hue=df_new['listing_review_score'])
plt.title('NUMBER OF ADULT VISIT VS REVIEW STARS', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('NUMBER OF ADULT', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.ylabel('listing_review_score', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # is_brand
# Integer	+1 if the hotel is part of a major hotel chain;
#  0 if it is an independent hotel

# %%
df_new['is_brand'].value_counts()/len(df_new)*100
# Out:
# 1    63.468802
# 0    36.531198
# Name: is_brand, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize=(6,5))
sns.countplot(df_new['is_brand'])
plt.title('is_brand')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(6,5))
df.groupby('is_brand')['booked'].mean().sort_values(ascending = False).plot(kind='bar')
plt.title('NUMBERS OF ADULT VS is_brand')
plt.legend()
plt.show()

# %%
df_new['has_promotion'].value_counts()/len(df_new)*100
# Out:
# 0    78.507635
# 1    21.492365
# Name: has_promotion, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize=(6,5))
sns.countplot(df_new['has_promotion'])
plt.title('has_promotion')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# NUMBER OF ADULT

# %%
df_new['num_adults'].value_counts()/len(df_new)*100
# Out:
# 2    65.348278
# 1    23.527603
# 4     4.883185
# 3     4.755694
# 6     0.603598
# 5     0.545839
# 8     0.207893
# 7     0.100733
# 9     0.027179
# Name: num_adults, dtype: float64

# %%
plt.style.use('default')
plt.figure(figsize=(10, 7))
sns.countplot(df_new['num_adults'], hue=df_new['booked'])
plt.title('NUMBER OF ADULT DONE BOOKING', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('BOOKED', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.ylabel('NUMBER OF ADULT', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.style.use('default')
plt.figure(figsize=(10, 7))
sns.countplot(df_new['num_adults'], hue=df_new['clicked'])
plt.title('NUMBER OF ADULT  VS CLICKED', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('NUMBER OF ADULT', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.ylabel('CLICKED', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# NUMBERS OF KIDS

# %%
df_new['num_kids'].value_counts()/len(df_new)*100
# Out:
# 0    76.837228
# 1    13.761863
# 2     7.739155
# 3     1.172793
# 4     0.373736
# 5     0.056961
# 6     0.039235
# 7     0.011930
# 8     0.006511
# 9     0.000588
# Name: num_kids, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize=(10,7))
sns.countplot(df_new['num_kids'],hue=df_new['booked'])
plt.title('NUMBERS OF KIDS VS BOOKED')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_new['num_rooms'].value_counts()/len(df_new)*100
# Out:
# 1    91.190843
# 2     7.470983
# 3     0.878618
# 4     0.262250
# 5     0.082124
# 6     0.045200
# 8     0.042427
# 7     0.027557
# Name: num_rooms, dtype: float64

# %% [markdown]
# STAY ON SATURDAY

# %%
df_new['stay_on_saturday'].value_counts()/len(df_new)*100
# Out:
# 0    50.173384
# 1    49.826616
# Name: stay_on_saturday, dtype: float64

# %%
plt.style.use('default')
plt.figure(figsize=(10, 7))
sns.countplot(df_new['num_adults'], hue=df_new['stay_on_saturday'])
plt.title('NUMBER OF ADULT STAY ON SATURDAY', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('NUMBER OF ADULT', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.ylabel('STAY ON SATURDAY', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.style.use('default')
plt.figure(figsize=(10, 7))
sns.countplot(df_new['num_kids'], hue=df_new['stay_on_saturday'])
plt.title('NUMBER OF KIDS VS BOOKING ON STURDAY ', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('NUMBER OF KIDS', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.ylabel('STAY ON SATURDAY', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_new['booked'].value_counts()/len(df_new)*100
# Out:
# 0    97.211241
# 1     2.788759
# Name: booked, dtype: float64

# %%
plt.style.use('default')
plt.figure(figsize=(6,5))
sns.countplot(df_new['booked'])
plt.title('BOOKED', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('BOOKED', fontdict={'fontname': 'Monospace', 'fontsize': 15})

plt.tick_params(labelsize=12)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
df_new['clicked'].value_counts()/len(df_new)*100
# Out:
# 0    95.543312
# 1     4.456688
# Name: clicked, dtype: float64

# %%
plt.style.use('default')
plt.figure(figsize=(6,5))
sns.countplot(df_new['clicked'])
plt.title('CLICKED', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('CLICKED', fontdict={'fontname': 'Monospace', 'fontsize': 15})

plt.tick_params(labelsize=12)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
df_new.columns
# Out:
# Index(['listing_stars', 'listing_review_score', 'is_brand', 'location_score1',
#        'location_score2', 'log_historical_price', 'listing_position',
#        'price_usd', 'has_promotion', 'length_of_stay', 'booking_window',
#        'num_adults', 'num_kids', 'num_rooms', 'stay_on_saturday',
#        'distance_to_dest', 'random_sort', 'clicked', 'booked'],
#       dtype='object')

# %%
df.groupby('listing_review_score')[ 'clicked'].mean().sort_values(ascending=False).plot(kind='bar')

# %%
df['listing_review_score'].head()
# Out:
# 0    4.0
# 1    4.0
# 2    4.5
# 3    4.0
# 4    4.5
# Name: listing_review_score, dtype: float64

# %% [markdown]
# CLICKED VS LISTING STARS

# %%
df.groupby('listing_stars')[ 'clicked'].mean().sort_values(ascending=False).plot(kind='bar')

# %%
relation_ship = df['listing_stars'].value_counts()/len(df)*100
plt.figure(figsize=(10,7))
plt.style.use('default')
plt.pie(relation_ship ,labels= relation_ship.index, explode = (0,0,0,0.20,0,0),shadow =True , autopct = '%1.1f%%')
plt.title('LISTING_STARS')
# Out:
# Text(0.5, 1.0, 'LISTING_STARS')

# %%
plt.figure(figsize=(16,12))
sns.heatmap(df_new.corr(), annot = True)
plt.title('CORRELATION')
plt.show()

# %% [markdown]
# CHECKING SKEWNESS

# %% [markdown]
# A skewness value greater than 1 or less than -1 indicates a highly skewed distribution. A value between 0.5 and 1 or -0.5 and -1 is moderately skewed. A value between -0.5 and 0.5 indicates that the distribution is fairly symmetrical.

# %%
df_new.head()
# Out:
#    listing_stars  listing_review_score  is_brand  location_score1  \
# 0              4                   4.0         0             3.22
# 1              4                   4.0         0             2.71
# 2              5                   4.5         1             3.22
# 3              3                   4.0         0             3.26
# 4              5                   4.5         0             3.09
#
#    location_score2  log_historical_price  listing_position  price_usd  \
# 0           0.2544                  5.98                21      295.0
# 1           0.0694                  5.64                36      299.0
# 2           0.1924                  6.10                22      373.0
# 3           0.3729                  5.74                 4      329.0
# 4           0.2508                  6.21                26      600.0
#
#    has_promotion  length_of_stay  booking_window  num_adults  num_kids  \
# 0              0               2              46           1         0
# 1              0               2              46           1         0
# 2              1               2              46           1         0
# 3              0               2              46           1         0
# 4              0               2              46           1         0
#
#    num_rooms  stay_on_saturday  distance_to_dest  random_sort  clicked  booked
# 0          1                 1            238.35            1        0       0
# 1          1                 1            238.34            1        0       0
# 2          1                 1            238.33            1        0       0
# 3          1                 1            238.29            1        0       0
# 4          1                 1            238.35            1        0       0

# %%
df_new.skew()
# Out:
# listing_stars            -0.666650
# listing_review_score     -2.244673
# is_brand                 -0.559432
# location_score1           0.132128
# location_score2           2.373392
# log_historical_price     -1.726552
# listing_position          0.179594
# price_usd               453.804919
# has_promotion             1.388013
# length_of_stay            3.484501
# booking_window            2.399389
# num_adults                2.328857
# num_kids                  2.465520
# num_rooms                 6.344249
# stay_on_saturday          0.006935
# distance_to_dest          3.066716
# random_sort               0.889906
# clicked                   4.414166
# booked                    5.734716
# dtype: float64

# %% [markdown]
# HANDLING SKEWNESS

# %%
cols=['price_usd','has_promotion','length_of_stay',
       'booking_window', 'num_adults', 'num_kids','num_rooms','clicked','booked']
for col in cols:
  print(col)
  print("skewness of columns are : ",skew(df[col]))

  plt.figure()
  sns.distplot(df[col],kde=True )

  plt.show()
# Out:
# price_usd
# skewness of columns are :  453.8046333342094
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# has_promotion
# skewness of columns are :  1.3880117216586376
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# length_of_stay
# skewness of columns are :  3.4844992744650694
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# booking_window
# skewness of columns are :  2.39938763369409
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# num_adults
# skewness of columns are :  2.32885581230151
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# num_kids
# skewness of columns are :  2.4655187757493833
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# num_rooms
# skewness of columns are :  6.344245377493231
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# clicked
# skewness of columns are :  4.414162732227842
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# booked
# skewness of columns are :  5.7347127280337045
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
cols=['price_usd','has_promotion','length_of_stay',
       'booking_window', 'num_adults', 'num_kids','num_rooms','clicked','booked']
for col in cols :
  df_new[col]=np.sqrt(df_new[col])

# %%
df_new.sample(20)
# Out:
#          listing_stars  listing_review_score  is_brand  location_score1  \
# 1746125              2                   3.0         0             1.10
# 891618               4                   4.5         1             2.08
# 590333               4                   4.0         1             3.04
# 1156888              3                   4.5         1             0.00
# 288510               4                   4.5         0             3.04
# 1597980              2                   4.5         1             0.69
# 294480               4                   3.5         0             2.94
# 28597                3                   3.5         1             0.69
# 2293427              2                   3.5         1             2.48
# 267943               3                   3.0         0             3.09
# 791513               2                   3.5         0             3.40
# 2147969              3                   4.5         1             2.40
# 1359177              3                   0.0         0             3.58
# 1747486              3                   3.5         0             2.83
# 1457802              4                   4.0         1             3.40
# 2374472              3                   3.5         0             5.67
# 18700                3                   4.5         1             2.20
# 570702               3                   5.0         1             0.69
# 1681259              2                   3.5         0             5.18
# 1340109              2                   2.0         0             4.30
#
#          location_score2  log_historical_price  listing_position  price_usd  \
# 1746125           0.0334                  4.85                 3  10.488088
# 891618            0.0694                  5.37                24  15.132746
# 590333            0.0333                  5.05                24   9.433981
# 1156888           0.0694                  0.00                20  10.246951
# 288510            0.1017                  5.32                31  21.996363
# 1597980           0.0650                  4.30                15   8.602325
# 294480            0.0694                  4.59                28  10.535654
# 28597             0.0694                  0.00                18   9.974467
# 2293427           0.0694                  4.58                12   9.219544
# 267943            0.1455                  5.25                29  11.789826
# 791513            0.0699                  4.56                31  20.000000
# 2147969           0.0002                  4.80                10   9.848858
# 1359177           0.1505                  4.87                34  10.723339
# 1747486           0.0336                  4.72                19   8.443933
# 1457802           0.3822                  5.48                 3  20.297783
# 2374472           0.1594                  5.89                 6  15.022650
# 18700             0.0705                  5.46                12  12.726351
# 570702            0.2667                  4.66                 3   9.539392
# 1681259           0.0694                  4.94                28  11.045361
# 1340109           0.4498                  4.65                13   7.348469
#
#          has_promotion  length_of_stay  booking_window  num_adults  num_kids  \
# 1746125            0.0        1.732051       14.035669    1.414214  1.000000
# 891618             0.0        1.000000        0.000000    1.414214  1.414214
# 590333             1.0        1.732051        3.741657    1.414214  0.000000
# 1156888            0.0        1.414214        2.236068    1.414214  0.000000
# 288510             0.0        1.000000       10.295630    1.414214  0.000000
# 1597980            0.0        1.000000        0.000000    1.000000  0.000000
# 294480             0.0        1.414214        2.645751    1.414214  0.000000
# 28597              0.0        3.000000        1.414214    1.000000  0.000000
# 2293427            0.0        1.000000        1.000000    1.000000  0.000000
# 267943             0.0        1.000000        3.162278    1.414214  0.000000
# 791513             0.0        1.000000        3.741657    1.414214  0.000000
# 2147969            0.0        2.000000        9.380832    1.000000  1.000000
# 1359177            0.0        2.236068        3.872983    1.414214  0.000000
# 1747486            1.0        1.732051       11.000000    1.414214  1.000000
# 1457802            0.0        1.414214        9.219544    1.000000  0.000000
# 2374472            1.0        1.732051        4.690416    1.414214  0.000000
# 18700              0.0        2.449490        7.416198    1.414214  0.000000
# 570702             0.0        1.732051        3.741657    1.000000  1.414214
# 1681259            0.0        1.732051        5.385165    1.414214  0.000000
# 1340109            0.0        1.414214        4.123106    1.414214  0.000000
#
#          num_rooms  stay_on_saturday  distance_to_dest  random_sort  clicked  \
# 1746125   1.000000                 0              1.78            0      1.0
# 891618    1.000000                 0            392.30            0      0.0
# 590333    1.000000                 0            362.63            0      0.0
# 1156888   1.000000                 1            119.94            0      0.0
# 288510    1.000000                 1            392.30            0      0.0
# 1597980   1.000000                 0            228.85            0      0.0
# 294480    1.000000                 1            392.30            0      0.0
# 28597     1.000000                 0            392.30            1      0.0
# 2293427   1.000000                 1           1245.23            0      0.0
# 267943    1.000000                 0             39.07            0      0.0
# 791513    1.000000                 0             27.91            0      0.0
# 2147969   1.414214                 1            392.30            0      0.0
# 1359177   1.000000                 0            392.30            1      0.0
# 1747486   1.000000                 0            392.30            1      0.0
# 1457802   1.000000                 0           4487.16            1      0.0
# 2374472   1.414214                 1            392.30            0      0.0
# 18700     1.000000                 0            392.30            0      0.0
# 570702    1.000000                 1           1002.35            0      0.0
# 1681259   1.000000                 0           2589.25            0      0.0
# 1340109   1.000000                 0            156.71            0      0.0
#
#          booked
# 1746125     1.0
# 891618      0.0
# 590333      0.0
# 1156888     0.0
# 288510      0.0
# 1597980     0.0
# 294480      0.0
# 28597       0.0
# 2293427     0.0
# 267943      0.0
# 791513      0.0
# 2147969     0.0
# 1359177     0.0
# 1747486     0.0
# 1457802     0.0
# 2374472     0.0
# 18700       0.0
# 570702      0.0
# 1681259     0.0
# 1340109     0.0

# %%
df_new.isnull().sum()
# Out:
# listing_stars           0
# listing_review_score    0
# is_brand                0
# location_score1         0
# location_score2         0
# log_historical_price    0
# listing_position        0
# price_usd               0
# has_promotion           0
# length_of_stay          0
# booking_window          0
# num_adults              0
# num_kids                0
# num_rooms               0
# stay_on_saturday        0
# distance_to_dest        0
# random_sort             0
# clicked                 0
# booked                  0
# dtype: int64

# %%
X = df_new.drop(['booked'],axis=1)
y = df_new['booked']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2,train_size=0.8 ,random_state = 50)

# %%
print("Number of booked X_train dataset: ", X_train.shape)
print("Number of booked y_train dataset: ", y_train.shape)
print("Number of booked X_test dataset: ", X_test.shape)
print("Number of booked y_test dataset: ", y_test.shape)
# Out:
# Number of booked X_train dataset:  (1904445, 18)
# Number of booked y_train dataset:  (1904445,)
# Number of booked X_test dataset:  (476112, 18)
# Number of booked y_test dataset:  (476112,)

# %%
print(X_train.ndim)
print(y_train.ndim)
# Out:
# 2
# 1

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
ss.fit_transform(X_train,y_train)
ss.transform(X_test)
# Out:
# array([[-0.17185111, -0.74456013, -1.31889774, ..., -0.46637706,
#         -0.64957944, -0.21597734],
#        [-1.12255288,  0.68649737, -1.31889774, ..., -0.36242841,
#          1.5394576 , -0.21597734],
#        [-0.17185111,  0.68649737, -1.31889774, ..., -0.32515548,
#         -0.64957944, -0.21597734],
#        ...,
#        [-0.17185111,  0.68649737,  0.7582089 , ..., -0.05510375,
#         -0.64957944, -0.21597734],
#        [-0.17185111,  0.68649737,  0.7582089 , ..., -0.34108731,
#         -0.64957944, -0.21597734],
#        [-0.17185111,  0.68649737,  0.7582089 , ...,  0.00860034,
#          1.5394576 ,  4.63011537]])

# %% [markdown]
# RANDOM SAMPLING

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
rus = RandomUnderSampler(random_state=42)
X_res,y_res = rus.fit_resample(X_train,y_train)

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression 
lr = LogisticRegression()
lr.fit(X_res,y_res)
print("The score of logistic Regression : ",lr.score(X_test,y_test))
# Out:
# The score of logistic Regression :  0.9800866182746917
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
lr_predict = lr.predict(X_test)

# %%
print(classification_report(lr_predict,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99    453373
#          1.0       1.00      0.58      0.74     22739
#
#     accuracy                           0.98    476112
#    macro avg       0.99      0.79      0.86    476112
# weighted avg       0.98      0.98      0.98    476112

# %%
data = pd.DataFrame(data={"Predicted booked":lr_predict, "Actual booked":y_test})
data.head(10)
# Out:
#          Predicted booked  Actual booked
# 2118795               0.0            0.0
# 253326                0.0            0.0
# 1508901               0.0            0.0
# 674105                1.0            0.0
# 336746                0.0            0.0
# 1385517               0.0            0.0
# 1170680               0.0            0.0
# 669449                0.0            0.0
# 1423324               0.0            0.0
# 1884161               0.0            0.0

# %% [markdown]
# CONFUSION MATRIX OF LOGISTIC REGRSSION

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,lr_predict)   # Y_test = actual value   y_pred = predicted value
# Out:
# array([[453352,   9460],
#        [    21,  13279]])

# %%
pd.crosstab(y_test,lr_predict)
# Out:
# col_0      0.0    1.0
# booked
# 0.0     453352   9460
# 1.0         21  13279

# %%
#  455282,13286  ------- predicted correctly as booked
# 157600 3433 ----- this are the mistake done by classifer

# %% [markdown]
# Accuracy of LOGISTIC REGRESSION

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,lr_predict)*100
# Out:
# 98.00866182746917

# %%
from sklearn.metrics import roc_auc_score,plot_roc_curve,plot_precision_recall_curve

# %%
roc_auc_score(y_test,lr_predict)
# Out:
# 0.9889903937349577

# %%
plot_roc_curve(lr,X_test,y_test)
plt.plot([0,1],[0,1], c='k')    #------ base line classifier
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_res,y_res)
print("The score of RandomForest : ",rf.score(X_test,y_test))
# Out:
# The score of RandomForest :  0.9843986288940417

# %%
rf_predict = rf.predict(X_test)

# %%
print(classification_report(rf_predict,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99    455420
#          1.0       1.00      0.64      0.78     20692
#
#     accuracy                           0.98    476112
#    macro avg       0.99      0.82      0.89    476112
# weighted avg       0.98      0.98      0.98    476112

# %%
data = pd.DataFrame(data={"Predicted booked":rf_predict, "Actual booked":y_test})
data.head(10)
# Out:
#          Predicted booked  Actual booked
# 2118795               0.0            0.0
# 253326                0.0            0.0
# 1508901               0.0            0.0
# 674105                1.0            0.0
# 336746                0.0            0.0
# 1385517               0.0            0.0
# 1170680               0.0            0.0
# 669449                0.0            0.0
# 1423324               0.0            0.0
# 1884161               0.0            0.0

# %%
pd.crosstab(y_test,rf_predict)
# Out:
# col_0      0.0    1.0
# booked
# 0.0     455402   7410
# 1.0         18  13282

# %% [markdown]
# ACURRACY OF RANDOM FOREST

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,rf_predict)*100
# Out:
# 98.43986288940417

# %% [markdown]
# ROC AND AUC CURVE OF RANDOM FOREST

# %%
roc_auc_score(y_test,rf_predict)
# Out:
# 0.9913178978664522

# %%
plot_roc_curve(rf,X_test,y_test)
plt.plot([0,1],[0,1], c='k')    #------ base line classifier
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# XGBOOST

# %%
import xgboost as xgb
model=xgb.XGBClassifier(learning_rate=0.1,max_depth=50,n_estimators=50)
model.fit(X_res, y_res)
print("The score of XGBOOST: ",model.score(X_test,y_test))
# Out:
# The score of XGBOOST:  0.9848165977753134

# %%
model_predict = model.predict(X_test)

# %%
print(classification_report(model_predict,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99    455633
#          1.0       1.00      0.65      0.79     20479
#
#     accuracy                           0.98    476112
#    macro avg       0.99      0.82      0.89    476112
# weighted avg       0.99      0.98      0.98    476112

# %%
data = pd.DataFrame(data={"Predicted booked":model_predict, "Actual booked":y_test})
data.head(10)
# Out:
#          Predicted booked  Actual booked
# 2118795               0.0            0.0
# 253326                0.0            0.0
# 1508901               0.0            0.0
# 674105                1.0            0.0
# 336746                0.0            0.0
# 1385517               0.0            0.0
# 1170680               0.0            0.0
# 669449                0.0            0.0
# 1423324               0.0            0.0
# 1884161               0.0            0.0

# %%
pd.crosstab(y_test,model_predict)
# Out:
# col_0      0.0    1.0
# booked
# 0.0     455608   7204
# 1.0         25  13275

# %%
plot_roc_curve(model,X_test,y_test)
plt.plot([0,1],[0,1], c='k')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
